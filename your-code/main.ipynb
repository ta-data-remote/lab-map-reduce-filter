# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %%
# Import reduce from functools, numpy and pandas
from functools import reduce 
import numpy
import functools

# %% [markdown]
# # Challenge 1 - Mapping
#
# #### We will use the map function to clean up words in a book.
#
# In the following cell, we will read a text file containing the book The Prophet by Khalil Gibran.

# %%
# Run this code:

location = '../data/58585-0.txt'
with open(location, 'r', encoding="utf8") as f:
    prophet = f.read().split(' ')
#print(prophet)

# %% [markdown]
# #### Let's remove the first 568 words since they contain information about the book but are not part of the book itself.
#
# Do this by removing from `prophet` elements 0 through 567 of the list (you can also do this by keeping elements 568 through the last element).

# %%
clean_list = prophet[569:]
#print(clean_list)

# %% [markdown]
# If you look through the words, you will find that many words have a reference attached to them. For example, let's look at words 1 through 10.

# %%
#print([clean_list[0]])
#print([clean_list[1]])
#print([clean_list[2]])
#print([clean_list[3]])
#print([clean_list[4]])
#print([clean_list[5]])
#print([clean_list[6]])
#print([clean_list[7]])
#print([clean_list[8]])
#print([clean_list[9]])

print(clean_list[:10])
# Out:
# ['the{7}', 'chosen', 'and', 'the\nbeloved,', 'who', 'was', 'a', 'dawn', 'unto', 'his']

# %% [markdown]
# #### The next step is to create a function that will remove references.
#
# We will do this by splitting the string on the `{` character and keeping only the part before this character. Write your function below.

# %%
def reference(x):
    '''
    Input: A string
    Output: The string with references removed
    
    Example:
    Input: 'the{7}'
    Output: 'the'
    '''
    #y = x.index("{")
    index = x.find("{")
    x = x[:index]
    print(index) #index returns -1 when "{" is not found, could not find another solution
    return x

reference(clean_list[1])
# Out:
# -1
# 'chose'

# %% [markdown]
# Now that we have our function, use the `map()` function to apply this function to our book, The Prophet. Return the resulting list to a new list called `prophet_reference`.

# %%
#new_list1 = []

#for i in prophet:
#    new_list1.append(reference(i))

#print(new_list1)

prophet_reference = list(map(reference, prophet))
print(prophet_reference)

#last letter missing in the words because of the index problem from before
# Out:
# ei', 'pleasures\nwit', 'gratitude', 'a', 'the', 'woul', 'the\nharves', 'o', '', 'summer.\n\nYe', 'i', 'i', 'comfort', 'the', 't', 'regret', 'let\nthe', 'b', 'comforted.\n\nAn', 'ther', 'ar', 'amon', 'yo', 'thos', 'who\nar', 'neithe', 'youn', 't', 'see', 'no', 'ol', 'to\nremember;\n\nAn', 'i', 'thei', 'fea', 'o', 'seekin', 'and\nrememberin', '', 'shu', 'al', 'pleasures,\nles', 'the', 'neglec', 'th', 'spiri', 'o', 'offend\nagains', 'it.\n\nBu', 'eve', 'i', 'thei', 'foregoin', 'i', 'their\npleasure.\n\nAn', 'thu', 'the', 'to', 'fin', '', 'treasur', 'though\nthe', 'di', 'fo', 'root', 'wit', 'quiverin', 'hands.\n\nBu', 'tel', 'me', 'wh', 'i', 'h', 'tha', 'ca', 'offend\nth', 'spirit?\n\nShal', 'th', 'nightingal', 'offen', 'the\nstillnes', 'o', 'th', 'night', 'o', 'th', 'firefly\nth', 'stars?\n\nAn', 'shal', 'you', 'flam', 'o', 'you', 'smoke\nburde', 'th', 'wind?\n\nThin', 'yo', 'th', 'spiri', 'i', '', 'stil', 'pool\nwhic', 'yo', 'ca', 'troubl', 'wit', '', 'staff?\n\n*****\n\nOftentime', 'i
# ...

# %% [markdown]
# Another thing you may have noticed is that some words contain a line break. Let's write a function to split those words. Our function will return the string split on the character `\n`. Write your function in the cell below.

# %%
def line_break(x):
    '''
    Input: A string
    Output: A list of strings split on the line break (\n) character
        
    Example:
    Input: 'the\nbeloved'
    Output: ['the', 'beloved']
    '''
    
    x = x.split("\n")
    return x

#line_break("the\nbeloved")
line_break(clean_list[4])
# Out:
# ['who']

# %% [markdown]
# Apply the `line_break` function to the `prophet_reference` list. Name the new list `prophet_line`.

# %%
prophet_line = []

for i in prophet_reference:
    prophet_line.append(line_break(i))
    
print(prophet_line)
# Out:
# amon'], ['you'], ['and', 'briefe'], ['stil'], ['th'], ['word'], [''], ['hav'], ['spoken.', '', 'Bu'], ['shoul'], ['m'], ['voic'], ['fad'], ['i'], ['you'], ['ears,', 'an'], ['m'], ['lov'], ['vanis'], ['i'], ['you'], ['memory'], ['then', ''], ['wil'], ['com'], ['again,', '', 'An'], ['wit'], [''], ['riche'], ['hear'], ['an'], ['lip'], ['more', 'yieldin'], ['t'], ['th'], ['spiri'], ['wil'], [''], ['speak.', '', 'Yea'], [''], ['shal'], ['retur'], ['wit'], ['th'], ['tide,', '', 'An'], ['thoug'], ['deat'], ['ma'], ['hid'], ['me'], ['an'], ['the', 'greate'], ['silenc'], ['enfol'], ['me'], ['ye'], ['again', 'wil'], [''], ['see'], ['you'], ['understanding.', '', 'An'], ['no'], ['i'], ['vai'], ['wil'], [''], ['seek.', '', 'I'], ['augh'], [''], ['hav'], ['sai'], ['i'], ['truth'], ['that', 'trut'], ['shal'], ['revea'], ['itsel'], ['i'], [''], ['clearer', 'voice'], ['an'], ['i'], ['word'], ['mor'], ['ki'], ['t'], ['your', 'thoughts.', '', ''], ['g'], ['wit'], ['th'], ['wind'], ['peopl'], ['of', 'O
# ...

# %% [markdown]
# If you look at the elements of `prophet_line`, you will see that the function returned lists and not strings. Our list is now a list of lists. Flatten the list using list comprehension. Assign this new list to `prophet_flat`.

# %%
prophet_flat = [i for substring in prophet_line for i in substring]

#for substring in prophet_line:
#    for i in substring:
#        prophet_flat.append(i)
prophet_flat
# Out:
# ['\ufeffTh',
#  'Projec',
#  'Gutenber',
#  'EBoo',
#  'o',
#  'Th',
#  'Prophet',
#  'b',
#  'Kahli',
#  'Gibran',
#  '',
#  'Thi',
#  'eBoo',
#  'i',
#  'fo',
#  'th',
#  'us',
#  'o',
#  'anyon',
#  'anywher',
#  'i',
#  'th',
#  'Unite',
#  'State',
#  'and',
#  'mos',
#  'othe',
#  'part',
#  'o',
#  'th',
#  'worl',
#  'a',
#  'n',
#  'cos',
#  'an',
#  'wit',
#  'almos',
#  'n',
#  'restrictions',
#  'whatsoever',
#  '',
#  'Yo',
#  'ma',
#  'cop',
#  'it',
#  'giv',
#  'i',
#  'awa',
#  'o',
#  're-us',
#  'i',
#  'unde',
#  'th',
#  'terms',
#  'o',
#  'th',
#  'Projec',
#  'Gutenber',
#  'Licens',
#  'include',
#  'wit',
#  'thi',
#  'eBoo',
#  'o',
#  'onlin',
#  'at',
#  'www.gutenberg.org',
#  '',
#  'I',
#  'yo',
#  'ar',
#  'no',
#  'locate',
#  'i',
#  'th',
#  'Unite',
#  'States',
#  "you'll",
#  'hav',
#  't',
#  'chec',
#  'th',
#  'law',
#  'o',
#  'th',
#  'countr',
#  'wher',
#  'yo',
#  'ar',
#  'locate',
#  'befor',
#  'using',
#  'thi',
#  'ebook.',
#  '',
# ...

# %% [markdown]
# # Challenge 2 - Filtering
#
# When printing out a few words from the book, we see that there are words that we may not want to keep if we choose to analyze the corpus of text. Below is a list of words that we would like to get rid of. Create a function that will return false if it contains a word from the list of words specified and true otherwise.

# %%
def word_filter(x):
    '''
    Input: A string
    Output: True if the word is not in the specified list 
    and False if the word is in the list.
        
    Example:
    word list = ['and', 'the']
    Input: 'and'
    Output: False
    
    Input: 'John'
    Output: True
    '''
    
    word_list = ['and', 'the', 'a', 'an']
    
    if i in word_list:
        return False
    else:
        return True
word_filter(prophet[5])
# Out:
# True

# %% [markdown]
# Use the `filter()` function to filter out the words speficied in the `word_filter()` function. Store the filtered list in the variable `prophet_filter`.

# %%
prophet_filter = list(filter(word_filter, prophet_flat))
prophet_filter
# Out:
# ['\ufeffTh',
#  'Projec',
#  'Gutenber',
#  'EBoo',
#  'o',
#  'Th',
#  'Prophet',
#  'b',
#  'Kahli',
#  'Gibran',
#  '',
#  'Thi',
#  'eBoo',
#  'i',
#  'fo',
#  'th',
#  'us',
#  'o',
#  'anyon',
#  'anywher',
#  'i',
#  'th',
#  'Unite',
#  'State',
#  'and',
#  'mos',
#  'othe',
#  'part',
#  'o',
#  'th',
#  'worl',
#  'a',
#  'n',
#  'cos',
#  'an',
#  'wit',
#  'almos',
#  'n',
#  'restrictions',
#  'whatsoever',
#  '',
#  'Yo',
#  'ma',
#  'cop',
#  'it',
#  'giv',
#  'i',
#  'awa',
#  'o',
#  're-us',
#  'i',
#  'unde',
#  'th',
#  'terms',
#  'o',
#  'th',
#  'Projec',
#  'Gutenber',
#  'Licens',
#  'include',
#  'wit',
#  'thi',
#  'eBoo',
#  'o',
#  'onlin',
#  'at',
#  'www.gutenberg.org',
#  '',
#  'I',
#  'yo',
#  'ar',
#  'no',
#  'locate',
#  'i',
#  'th',
#  'Unite',
#  'States',
#  "you'll",
#  'hav',
#  't',
#  'chec',
#  'th',
#  'law',
#  'o',
#  'th',
#  'countr',
#  'wher',
#  'yo',
#  'ar',
#  'locate',
#  'befor',
#  'using',
#  'thi',
#  'ebook.',
#  '',
# ...

# %% [markdown]
# # Bonus Challenge
#
# Rewrite the `word_filter` function above to not be case sensitive.

# %%
def word_filter_case(x):
   
    word_list = ['and', 'the', 'a', 'an']
    
    # your code here

# %% [markdown]
# # Challenge 3 - Reducing
#
# #### Now that we have significantly cleaned up our text corpus, let's use the `reduce()` function to put the words back together into one long string separated by spaces.
#
# We will start by writing a function that takes two strings and concatenates them together with a space between the two strings.

# %%
def concat_space(a, b):
    '''
    Input:Two strings
    Output: A single string separated by a space
        
    Example:
    Input: 'John', 'Smith'
    Output: 'John Smith'
    '''
    new_str = a + " " + b
    return new_str

concat_space('John', 'Smith')
# Out:
# 'John Smith'

# %% [markdown]
# Use the function above to reduce the text corpus in the list `prophet_filter` into a single string. Assign this new string to the variable `prophet_string`.

# %%
prophet_string = reduce(concat_space, prophet_filter)
print(prophet_string)
#Letters missing from many words, mistake not found
# Out:
# ole o th serpent.  you god-sel dwell no alone i you being.  Muc i yo i stil man an muc in yo i no ye man,  Bu  shapeles pigm tha walk asleep i th mis searchin fo it own awakening.  An o th ma i yo woul  no speak.  Fo i i h an no you god-sel nor th pigm i th mist tha know crime an th punishmen o crime.  *****  Oftentime hav  hear yo spea o one wh commit  wron a thoug h were no on o you bu  strange unt you an a intrude upo you world.  Bu  sa tha eve a th hol an the righteou canno ris beyon th highest whic i i eac on o you,  S th wicke an th wea canno fall lowe tha th lowes whic i i you also.  An a  singl lea turn no yellow bu wit th silen knowledg o the whol tree  th wrong-doe cannot d wron withou th hidde wil o you all.  Lik  processio yo wal together toward you god-self.  [Illustration 0064]  Yo ar th wa an th wayfarers.  An whe on o yo fall dow h falls fo thos behin him  cautio against th stumblin stone.  Ay an h fall fo thos ahea o him, wh thoug faste an sure o foot yet remove no t
# ...
